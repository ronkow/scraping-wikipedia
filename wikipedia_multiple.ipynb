# %%
import pandas as pd

# search for <table> tags and parses all text within the tags
tables = pd.read_html("https://en.wikipedia.org/wiki/1998_in_film")

# print the number of DataFrames in the list
len(tables)
# Out:
# 11

# %%
df_1998oct = tables[8]
df_1998oct.tail(25)
# Out:
#      Opening              Opening.1  \
# 25  NOVEMBER                     20
# 26  NOVEMBER                     20
# 27  NOVEMBER  Babe: Pig in the City
# 28  NOVEMBER             Home Fries
# 29  NOVEMBER             Ringmaster
# 30  NOVEMBER        Very Bad Things
# 31  DECEMBER                      4
# 32  DECEMBER                      4
# 33  DECEMBER                     11
# 34  DECEMBER                     11
# 35  DECEMBER                     11
# 36  DECEMBER                     11
# 37  DECEMBER                     18
# 38  DECEMBER                     18
# 39  DECEMBER                     18
# 40  DECEMBER                     23
# 41  DECEMBER                     25
# 42  DECEMBER                     25
# 43  DECEMBER                     25
# 44  DECEMBER                     25
# 45  DECEMBER                     25
# 46  DECEMBER                     30
# 47  DECEMBER                     30
# 48  DECEMBER                     30
# 49  DECEMBER                     30
#
#                                                 Title  \
# 25                                         Waking Ned
# 26                                                 25
# 27                                                 25
# 28                                                 25
# 29                                                 25
# 30  PolyGram Filmed Entertainment / Interscope Com...
# 31                                       Little Voice
# 32                                             Psycho
# 33                                         Jack Frost
# 34                                Shakespeare in Love
# 35                                      A Simple Plan
# 36                            Star Trek: Insurrection
# 37                                   Playing by Heart
# 38                                The Prince of Egypt
# 39                                    You've Got Mail
# 40                                  The Thin Red Line
# 41                                     A Civil Action
# 42                                        The Faculty
# 43                                   Mighty Joe Young
# 44                                        Patch Adams
# 45                                            Stepmom
# 46                                         Affliction
# 47                            Another Day in Paradise
# 48                                  Hilary and Jackie
# 49                                  The Hi-Lo Country
#
#                                                Studio  \
# 25                  Fox Searchlight Pictures / Canal+
# 26                                       A Bug's Life
# 27    Universal Pictures / Kennedy Miller Productions
# 28                              Warner Bros. Pictures
# 29  Artisan Entertainment / The Kushner-Locke Company
# 30  Peter Berg (director/screenplay); Cameron Diaz...
# 31                                      Miramax Films
# 32         Universal Pictures / Imagine Entertainment
# 33                              Warner Bros. Pictures
# 34                 Miramax Films / Universal Pictures
# 35  Paramount Pictures / Mutual Film Company / Sav...
# 36                                 Paramount Pictures
# 37                  Miramax Films / Hyperion Pictures
# 38                                         DreamWorks
# 39                              Warner Bros. Pictures
# 40               Fox 2000 Pictures / Phoenix Pictures
# 41           Touchstone Pictures / Paramount Pictures
# 42  Miramax Films / Dimension Films / Los Hooligan...
# 43                Walt Disney Pictures / RKO Pictures
# 44                                 Universal Pictures
# 45                  Columbia Pictures / 1492 Pictures
# 46                                   Lions Gate Films
# 47                                   Trimark Pictures
# 48                                      October Films
# 49  Gramercy Pictures / PolyGram Filmed Entertainm...
#
#                                         Cast and crew  \
# 25  Kirk Jones (director/screenplay); Ian Bannen, ...
# 26     Walt Disney Pictures / Pixar Animation Studios
# 27  George Miller (director/screenplay); Judy Morr...
# 28  Dean Parisot (director); Vince Gilligan (scree...
# 29  Neil Abramson (director); Jon Bernstein (scree...
# 30                                             Comedy
# 31  Mark Herman (director/screenplay); Jane Horroc...
# 32  Gus Van Sant (director); Joseph Stefano (scree...
# 33  Troy Miller (director); Mark Steven Johnson, J...
# 34  John Madden (director); Marc Norman, Tom Stopp...
# 35  Sam Raimi (director); Scott B. Smith (screenpl...
# 36  Jonathan Frakes (director); Michael Piller (sc...
# 37  Willard Carroll (director/screenplay); Gillian...
# 38  Simon Wells, Brenda Chapman, Steve Hickner (di...
# 39  Nora Ephron (director/screenplay); Delia Ephro...
# 40  Terrence Malick (director/screenplay); Sean Pe...
# 41  Steve Zaillian (director/screenplay); John Tra...
# 42  Robert Rodriguez (director); Kevin Williamson ...
# 43  Ron Underwood (director); Merian C. Cooper, Ru...
# 44  Tom Shadyac (director); Steve Oedekerk (screen...
# 45  Chris Columbus (director); Gigi Levangie Graze...
# 46  Paul Schrader (director/screenplay); Nick Nolt...
# 47  Larry Clark (director); Stephen Chin, Christop...
# 48  Anand Tucker (director); Emily Watson, Rachel ...
# 49  Stephen Frears (director); Walon Green (screen...
#
#                                                 Genre  \
# 25                                             Comedy
# 26  John Lasseter (director); Andrew Stanton, Dona...
# 27                              Comedy, Drama, Family
# 28                             Comedy, Romance, Drama
# 29                                             Comedy
# 30                                        Live action
# 31                                            Musical
# 32                                             Horror
# 33                            Comedy, Fantasy, Family
# 34                             Romance, Comedy, Drama
# 35                                    Crime, Thriller
# 36                                     Sci-Fi, Action
# 37                                      Comedy, Drama
# 38                             Musical, Drama, Family
# 39                             Romance, Comedy, Drama
# 40                                         War, Drama
# 41                                              Drama
# 42                                     Sci-Fi, Horror
# 43                                  Adventure, Family
# 44                           Biography, Comedy, Drama
# 45                                      Comedy, Drama
# 46                                     Drama, Mystery
# 47                                              Drama
# 48                                   Drama, Biography
# 49                                     Western, Drama
#
#                        Medium Unnamed: 7
# 25                Live action        NaN
# 26  Adventure, Comedy, Family  Animation
# 27                Live action        NaN
# 28                Live action        NaN
# 29                Live action        NaN
# 30                        NaN        NaN
# 31                Live action        NaN
# 32                Live action        NaN
# 33                Live action        NaN
# 34                Live action        NaN
# 35                Live action        NaN
# 36                Live action        NaN
# 37                Live action        NaN
# 38                  Animation        NaN
# 39                Live action        NaN
# 40                Live action        NaN
# 41                Live action        NaN
# 42                Live action        NaN
# 43                Live action        NaN
# 44                Live action        NaN
# 45                Live action        NaN
# 46                Live action        NaN
# 47                Live action        NaN
# 48                Live action        NaN
# 49                Live action        NaN

# %%
# Correct the errors
df_1998oct.loc[26,'Title'] = df_1998oct.loc[26,'Studio']
df_1998oct.loc[26,'Studio'] = df_1998oct.loc[26,'Cast and crew']
df_1998oct.loc[26,'Cast and crew'] = df_1998oct.loc[26,'Genre']
df_1998oct.loc[26,'Genre'] = df_1998oct.loc[26,'Medium']
df_1998oct.loc[26,'Medium'] = df_1998oct.loc[26,'Unnamed: 7']

df_1998oct.loc[27,'Opening.1'] = 25
df_1998oct.loc[27,'Title'] = 'Babe: Pig in the City'

df_1998oct.loc[28,'Opening.1'] = 25
df_1998oct.loc[28,'Title'] = 'Home Fries'

df_1998oct.loc[29,'Opening.1'] = 25
df_1998oct.loc[29,'Title'] = 'Ringmaster'

df_1998oct.loc[30,'Medium'] = df_1998oct.loc[30,'Genre']  
df_1998oct.loc[30,'Genre'] = df_1998oct.loc[30,'Cast and crew']  
df_1998oct.loc[30,'Cast and crew'] = df_1998oct.loc[30,'Studio']  
df_1998oct.loc[30,'Studio'] = df_1998oct.loc[30,'Title']
df_1998oct.loc[30,'Title'] = df_1998oct.loc[30,'Opening.1']  
df_1998oct.loc[30,'Opening.1'] = 25

# %%
df_1998oct.columns
# Out:
# Index(['Opening', 'Opening.1', 'Title', 'Studio', 'Cast and crew', 'Genre',
#        'Medium', 'Unnamed: 7'],
#       dtype='object')

# %%
# Delete the last column
df_1998oct.drop(columns=['Unnamed: 7'], inplace=True)
df_1998oct.tail(25)
# Out:
#      Opening Opening.1                    Title  \
# 25  NOVEMBER        20               Waking Ned
# 26  NOVEMBER        20             A Bug's Life
# 27  NOVEMBER        25    Babe: Pig in the City
# 28  NOVEMBER        25               Home Fries
# 29  NOVEMBER        25               Ringmaster
# 30  NOVEMBER        25          Very Bad Things
# 31  DECEMBER         4             Little Voice
# 32  DECEMBER         4                   Psycho
# 33  DECEMBER        11               Jack Frost
# 34  DECEMBER        11      Shakespeare in Love
# 35  DECEMBER        11            A Simple Plan
# 36  DECEMBER        11  Star Trek: Insurrection
# 37  DECEMBER        18         Playing by Heart
# 38  DECEMBER        18      The Prince of Egypt
# 39  DECEMBER        18          You've Got Mail
# 40  DECEMBER        23        The Thin Red Line
# 41  DECEMBER        25           A Civil Action
# 42  DECEMBER        25              The Faculty
# 43  DECEMBER        25         Mighty Joe Young
# 44  DECEMBER        25              Patch Adams
# 45  DECEMBER        25                  Stepmom
# 46  DECEMBER        30               Affliction
# 47  DECEMBER        30  Another Day in Paradise
# 48  DECEMBER        30        Hilary and Jackie
# 49  DECEMBER        30        The Hi-Lo Country
#
#                                                Studio  \
# 25                  Fox Searchlight Pictures / Canal+
# 26     Walt Disney Pictures / Pixar Animation Studios
# 27    Universal Pictures / Kennedy Miller Productions
# 28                              Warner Bros. Pictures
# 29  Artisan Entertainment / The Kushner-Locke Company
# 30  PolyGram Filmed Entertainment / Interscope Com...
# 31                                      Miramax Films
# 32         Universal Pictures / Imagine Entertainment
# 33                              Warner Bros. Pictures
# 34                 Miramax Films / Universal Pictures
# 35  Paramount Pictures / Mutual Film Company / Sav...
# 36                                 Paramount Pictures
# 37                  Miramax Films / Hyperion Pictures
# 38                                         DreamWorks
# 39                              Warner Bros. Pictures
# 40               Fox 2000 Pictures / Phoenix Pictures
# 41           Touchstone Pictures / Paramount Pictures
# 42  Miramax Films / Dimension Films / Los Hooligan...
# 43                Walt Disney Pictures / RKO Pictures
# 44                                 Universal Pictures
# 45                  Columbia Pictures / 1492 Pictures
# 46                                   Lions Gate Films
# 47                                   Trimark Pictures
# 48                                      October Films
# 49  Gramercy Pictures / PolyGram Filmed Entertainm...
#
#                                         Cast and crew  \
# 25  Kirk Jones (director/screenplay); Ian Bannen, ...
# 26  John Lasseter (director); Andrew Stanton, Dona...
# 27  George Miller (director/screenplay); Judy Morr...
# 28  Dean Parisot (director); Vince Gilligan (scree...
# 29  Neil Abramson (director); Jon Bernstein (scree...
# 30  Peter Berg (director/screenplay); Cameron Diaz...
# 31  Mark Herman (director/screenplay); Jane Horroc...
# 32  Gus Van Sant (director); Joseph Stefano (scree...
# 33  Troy Miller (director); Mark Steven Johnson, J...
# 34  John Madden (director); Marc Norman, Tom Stopp...
# 35  Sam Raimi (director); Scott B. Smith (screenpl...
# 36  Jonathan Frakes (director); Michael Piller (sc...
# 37  Willard Carroll (director/screenplay); Gillian...
# 38  Simon Wells, Brenda Chapman, Steve Hickner (di...
# 39  Nora Ephron (director/screenplay); Delia Ephro...
# 40  Terrence Malick (director/screenplay); Sean Pe...
# 41  Steve Zaillian (director/screenplay); John Tra...
# 42  Robert Rodriguez (director); Kevin Williamson ...
# 43  Ron Underwood (director); Merian C. Cooper, Ru...
# 44  Tom Shadyac (director); Steve Oedekerk (screen...
# 45  Chris Columbus (director); Gigi Levangie Graze...
# 46  Paul Schrader (director/screenplay); Nick Nolt...
# 47  Larry Clark (director); Stephen Chin, Christop...
# 48  Anand Tucker (director); Emily Watson, Rachel ...
# 49  Stephen Frears (director); Walon Green (screen...
#
#                         Genre       Medium
# 25                     Comedy  Live action
# 26  Adventure, Comedy, Family    Animation
# 27      Comedy, Drama, Family  Live action
# 28     Comedy, Romance, Drama  Live action
# 29                     Comedy  Live action
# 30                     Comedy  Live action
# 31                    Musical  Live action
# 32                     Horror  Live action
# 33    Comedy, Fantasy, Family  Live action
# 34     Romance, Comedy, Drama  Live action
# 35            Crime, Thriller  Live action
# 36             Sci-Fi, Action  Live action
# 37              Comedy, Drama  Live action
# 38     Musical, Drama, Family    Animation
# 39     Romance, Comedy, Drama  Live action
# 40                 War, Drama  Live action
# 41                      Drama  Live action
# 42             Sci-Fi, Horror  Live action
# 43          Adventure, Family  Live action
# 44   Biography, Comedy, Drama  Live action
# 45              Comedy, Drama  Live action
# 46             Drama, Mystery  Live action
# 47                      Drama  Live action
# 48           Drama, Biography  Live action
# 49             Western, Drama  Live action

# %%
# Concatenate the tables for 1998
df_1998jan = tables[5]
df_1998apr = tables[6]
df_1998jul = tables[7]
df_1998 = pd.concat([df_1998jan, df_1998apr, df_1998jul, df_1998oct])

df_1998.insert(0, 'Year', '1998')
df_1998.head()
# Out:
#    Year  Opening Opening.1       Title  \
# 0  1998  JANUARY         9   Firestorm
# 1  1998  JANUARY        16      Fallen
# 2  1998  JANUARY        16  Half Baked
# 3  1998  JANUARY        16   Hard Rain
# 4  1998  JANUARY        23    Phantoms
#
#                                               Studio  \
# 0                                   20th Century Fox
# 1  Warner Bros. Pictures / Turner Pictures / Atla...
# 2                                 Universal Pictures
# 3  Paramount Pictures / PolyGram Filmed Entertain...
# 4                    Miramax Films / Dimension Films
#
#                                        Cast and crew             Genre  \
# 0  Dean Semler (director); Chris Soth (screenplay...  Action, Thriller
# 1  Gregory Hoblit (director); Nicholas Kazan (scr...          Thriller
# 2  Tamra Davis (director); Dave Chappelle, Neal B...            Comedy
# 3  Mikael Salomon (director); Graham Yost (screen...  Action, Thriller
# 4  Joe Chappelle (director); Dean Koontz (screenp...    Sci-Fi, Horror
#
#         Medium
# 0  Live action
# 1  Live action
# 2  Live action
# 3  Live action
# 4  Live action

# %%
# Concatenate the tables for all years
list_years = ['1990','1991','1992','1993','1994','1995','1996','1997','1998','1999']

df_1990s = pd.DataFrame()

for year in list_years:
    if year == '1998':
        df_1990s = pd.concat([df_1990s, df_1998])
    else:  
        tables = pd.read_html('https://en.wikipedia.org/wiki/' + year + '_in_film')
        df_jan = tables[5]
        df_apr = tables[6]
        df_jul = tables[7]
        df_oct = tables[8]
        df = pd.concat([df_jan, df_apr, df_jul, df_oct])
        df.insert(0, 'Year', year)
        df_1990s = pd.concat([df_1990s, df])

# %%
len(df_1990s)
# Out:
# 1573

# %%
# Rename two columns, reset the row index
df_1990s.rename(columns={'Opening':'Month', 'Opening.1':'Opening Date'}, inplace=True) 
df_1990s.reset_index(inplace=True, drop=True)
df_1990s.tail()
# Out:
#       Year     Month Opening Date                    Title  \
# 1568  1999  DECEMBER           25           Angela's Ashes
# 1569  1999  DECEMBER           25             Galaxy Quest
# 1570  1999  DECEMBER           25                 Magnolia
# 1571  1999  DECEMBER           25  The Talented Mr. Ripley
# 1572  1999  DECEMBER           29            The Hurricane
#
#                                        Studio  \
# 1568  Paramount Pictures / Universal Pictures
# 1569                               DreamWorks
# 1570                          New Line Cinema
# 1571       Paramount Pictures / Miramax Films
# 1572     Universal Pictures / Beacon Pictures
#
#                                           Cast and crew             Genre  \
# 1568  Alan Parker (director/screenplay); Laura Jones...             Drama
# 1569  Dean Parisot (director); Robert Gordon, David ...    Comedy, Sci-Fi
# 1570  Paul Thomas Anderson (director/screenplay); To...             Drama
# 1571  Anthony Minghella (director/screenplay); Matt ...   Thriller, Drama
# 1572  Norman Jewison (director); Armyan Bernstein, D...  Biography, Drama
#
#            Medium
# 1568  Live action
# 1569  Live action
# 1570  Live action
# 1571  Live action
# 1572  Live action

# %%
# Split the data into separate columns
df_genre = df_1990s['Genre'].str.split(',', expand=True)
df_castandcrew = df_1990s['Cast and crew'].str.split(';', expand=True)

# %%
df_genre.tail()
# Out:
#               0        1     2     3     4
# 1568      Drama     None  None  None  None
# 1569     Comedy   Sci-Fi  None  None  None
# 1570      Drama     None  None  None  None
# 1571   Thriller    Drama  None  None  None
# 1572  Biography    Drama  None  None  None

# %%
df_castandcrew.head()
# Out:
#                              0  \
# 0  Richard Benjamin (director)
# 1       Mike Figgis (director)
# 2         Jeff Burr (director)
# 3   Richard Correll (director)
# 4        Adam Simon (director)
#
#                                                    1  \
# 0                           Nat Mauldin (screenplay)
# 1                            Henry Bean (screenplay)
# 2                        David J. Schow (screenplay)
# 3   Steven Long Mitchell, Craig W. Van Sickle, Wi...
# 4          Charles Beaumont, Adam Simon (screenplay)
#
#                                                    2     3
# 0   Anthony Edwards, Forest Whitaker, Penelope An...  None
# 1   Richard Gere, Andy García, Nancy Travis, Laur...  None
# 2   Kate Hodge, Viggo Mortensen, William Butler, ...  None
# 3   Roger Rose, Yvette Nipar, T. K. Carter, Lesli...  None
# 4   Bill Pullman, Bill Paxton, Bud Cort, George K...  None

# %%
# Rename the new columns, delete the old columns
df_1990s['Genre1'] = df_genre[0]
df_1990s['Genre2'] = df_genre[1]
df_1990s['Genre3'] = df_genre[2]
df_1990s['Genre4'] = df_genre[3]
df_1990s['Genre5'] = df_genre[4]

df_1990s['Crew1'] = df_castandcrew[0]
df_1990s['Crew2'] = df_castandcrew[1]
df_1990s['Cast1'] = df_castandcrew[2]
df_1990s['Cast2'] = df_castandcrew[3]

df_1990s.drop(columns=['Cast and crew','Genre'], inplace=True)
df_1990s.head()
# Out:
#    Year    Month Opening Date                                         Title  \
# 0  1990  JANUARY           12                                      Downtown
# 1  1990  JANUARY           12                              Internal Affairs
# 2  1990  JANUARY           12  Leatherface: The Texas Chainsaw Massacre III
# 3  1990  JANUARY           12                                    Ski Patrol
# 4  1990  JANUARY           19                                    Brain Dead
#
#                Studio       Medium  Genre1     Genre2 Genre3 Genre4 Genre5  \
# 0    20th Century Fox  Live Action  Action     Comedy   None   None   None
# 1  Paramount Pictures  Live Action   Crime   Thriller   None   None   None
# 2     New Line Cinema  Live Action  Horror       None   None   None   None
# 3    Epic Productions  Live Action  Comedy       None   None   None   None
# 4            Concorde  Live Action  Horror   Thriller   None   None   None
#
#                          Crew1  \
# 0  Richard Benjamin (director)
# 1       Mike Figgis (director)
# 2         Jeff Burr (director)
# 3   Richard Correll (director)
# 4        Adam Simon (director)
#
#                                                Crew2  \
# 0                           Nat Mauldin (screenplay)
# 1                            Henry Bean (screenplay)
# 2                        David J. Schow (screenplay)
# 3   Steven Long Mitchell, Craig W. Van Sickle, Wi...
# 4          Charles Beaumont, Adam Simon (screenplay)
#
#                                                Cast1 Cast2
# 0   Anthony Edwards, Forest Whitaker, Penelope An...  None
# 1   Richard Gere, Andy García, Nancy Travis, Laur...  None
# 2   Kate Hodge, Viggo Mortensen, William Butler, ...  None
# 3   Roger Rose, Yvette Nipar, T. K. Carter, Lesli...  None
# 4   Bill Pullman, Bill Paxton, Bud Cort, George K...  None

# %%
# Create the CSV file
df_1990s.to_csv('films_1990s.csv', sep = ',', index = False)
